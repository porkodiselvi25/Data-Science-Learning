# %%
import pandas as pd

# %%
customer_data = pd.read_csv(r"C:\Users\admin\INTERNSHIP_TASK\MINI_DATA_CLEANING_PROJECT\data\customer.csv")

# %%
print("Original Data: \n")
print(customer_data)
# Out:
# Original Data:
#
#        Name   Age         City
# 0   Porkodi  22.0      Vellore
# 1     Laksh  23.0      Vellore
# 2    karthi  22.0      Chennai
# 3    Anitha   NaN      Madurai
# 4     Rahul  25.0   Coimbatore
# 5     Meena  21.0        Salem
# 6     Arjun  24.0       Trichy
# 7     Divya  22.0        Erode
# 8     Kavin   NaN      Chennai
# 9      Nila  23.0  Tirunelveli
# 10  Porkodi  22.0      Vellore

# %%
customer_data = customer_data.drop_duplicates()
print(customer_data)
# Out:
#       Name   Age         City
# 0  Porkodi  22.0      Vellore
# 1    Laksh  23.0      Vellore
# 2   karthi  22.0      Chennai
# 4    Rahul  25.0   Coimbatore
# 5    Meena  21.0        Salem
# 6    Arjun  24.0       Trichy
# 7    Divya  22.0        Erode
# 9     Nila  23.0  Tirunelveli

# %%
customer_data = customer_data.dropna() 
print(customer_data)
# Out:
#       Name   Age         City
# 0  Porkodi  22.0      Vellore
# 1    Laksh  23.0      Vellore
# 2   karthi  22.0      Chennai
# 4    Rahul  25.0   Coimbatore
# 5    Meena  21.0        Salem
# 6    Arjun  24.0       Trichy
# 7    Divya  22.0        Erode
# 9     Nila  23.0  Tirunelveli

# %%
print("\nData cleaned successfully!")
# Out:
# Data cleaned successfully!
