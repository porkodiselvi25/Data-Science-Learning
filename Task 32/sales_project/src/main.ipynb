# %%
import pandas as pd
import logging

def load_data(file_path):
    return pd.read_csv(file_path)

def get_summary(data):
    return data.describe()

def get_shape(data):
    return data.shape

def get_columns(data):
    return list(data.columns)

def check_missing_values(data):
    return data.isnull().sum()

logging.basicConfig(level=logging.INFO)

file_path = r"C:\Users\admin\PORKODI CLG\Data-Science-Learning\Task-32\sales_project\data\sales_data.csv"

df = load_data(file_path)

print(get_shape(df))
print(get_columns(df))
print(check_missing_values(df))
print(get_summary(df))
# Out:
# (5, 4)
# ['Product', 'Category', 'Sales', 'Profit']
# Product     0
# Category    0
# Sales       0
# Profit      0
# dtype: int64
#              Sales       Profit
# count      5.00000      5.00000
# mean   20100.00000   4620.00000
# std    19926.11352   4867.95645
# min      500.00000    100.00000
# 25%     8000.00000   1500.00000
# 50%    12000.00000   2500.00000
# 75%    30000.00000   7000.00000
# max    50000.00000  12000.00000
