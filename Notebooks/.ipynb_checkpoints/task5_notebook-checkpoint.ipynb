# %%
print("Task 5 - Feature Branch Practice")
# Out:
# Task 5 - Feature Branch Practice

# %%
name = "Porkodi"
dept = "M.Sc IT"

print("Name:", name)
print("Department:" ,dept )
# Out:
# Name: Porkodi
# Department: M.Sc IT
